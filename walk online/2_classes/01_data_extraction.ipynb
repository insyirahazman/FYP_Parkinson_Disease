# %% [markdown]
# ## Data Dictionary
# - **file_ID:** Name of the source file (without extension).
# - **image_id:** Identifier or filename of the original image.
# - **category_id:** Object category ID (1 for person).
# - **score:** Confidence score of the detection or prediction, ranges from 0 to 1
# - **label:** Class label assigned by folder (0 for NP, 1 for PD).
# - **keypoint_N:** Flattened coordinates and confidence for each keypoint. [x-coordinate, y-coordinate, and confidence]
# - **box_N:** The box of object

# %%
import os
import json
import cv2
import numpy as np
import pandas as pd
from pathlib import Path
from scipy.signal import savgol_filter, find_peaks
import matplotlib.pyplot as plt
import re

JSON_DIR = Path("D:/PD/PD_latest/dataset/online_dataset")  # e.g., PD_01.json
PROCESSED_DIR = Path("D:/PD/PD_latest/dataset/processed_cycles/online_2class")
CYCLES_DIR = PROCESSED_DIR / "cycles"
GROUPS_DIR = PROCESSED_DIR / "groups"
METADATA_PATH = PROCESSED_DIR / "metadata" / "cycle_metadata.csv"

CYCLES_DIR.mkdir(parents=True, exist_ok=True)
GROUPS_DIR.mkdir(parents=True, exist_ok=True)
(PROCESSED_DIR / "metadata").mkdir(parents=True, exist_ok=True)

DEFAULT_FPS = 30

# COCO keypoint indices
KEYPOINTS = {
    'nose': 0,
    'left_eye': 1, 'right_eye': 2,
    'left_ear': 3, 'right_ear': 4,
    'left_shoulder': 5, 'right_shoulder': 6,
    'left_elbow': 7, 'right_elbow': 8,
    'left_wrist': 9, 'right_wrist': 10,
    'left_hip': 11, 'right_hip': 12,
    'left_knee': 13, 'right_knee': 14,
    'left_ankle': 15, 'right_ankle': 16,
}

K = {name: i for i, name in enumerate(KEYPOINTS)}

COCO_EDGES = [
    (K['nose'], K['left_eye']), (K['left_eye'], K['left_ear']), 
    (K['nose'], K['right_eye']), (K['right_eye'], K['right_ear']),
    (K['left_shoulder'], K['left_elbow']), (K['left_elbow'], K['left_wrist']),
    (K['right_shoulder'], K['right_elbow']), (K['right_elbow'], K['right_wrist']),
    (K['left_shoulder'], K['right_shoulder']),
    (K['left_hip'], K['left_knee']), (K['left_knee'], K['left_ankle']),
    (K['right_hip'], K['right_knee']), (K['right_knee'], K['right_ankle']),
    (K['left_hip'], K['right_hip']),
    (K['left_shoulder'], K['left_hip']), (K['right_shoulder'], K['right_hip'])
]

# %%
def infer_label(file_path):
    """
    Infer label from folder structure:
    - Files in NP/ folder → '0'
    - Files in PD/ folder (any subfolder) → '1'
    
    Note: Check NP first because the root path may contain 'PD'
    """
    parts = Path(file_path).parts
    parts_upper = [p.upper() for p in parts]
    
    # Check NP first to avoid matching 'PD' in root path (e.g., 'PD_latest')
    if 'NP' in parts_upper:
        return '0'
    elif 'PD' in parts_upper:
        return '1'
    else:
        return 'UNK'

def infer_severity(file_path):
    """
    Extract severity level from PD folder structure:
    - PD/Mild → 'Mild'
    - PD/Moderate → 'Moderate'
    - PD/Severe → 'Severe'
    - Otherwise → None
    """
    parts = [p.lower() for p in Path(file_path).parts]
    
    if 'mild' in parts:
        return 'Mild'
    elif 'moderate' in parts:
        return 'Moderate'
    elif 'severe' in parts:
        return 'Severe'
    else:
        return None

def load_alphapose_json(json_path):
    """Load → (T, 34): [x0,y0,x1,y1,...,x16,y16]"""
    with open(json_path, 'r') as f:
        data = json.load(f)
    data_sorted = sorted(data, key=lambda x: x.get('image_id', x.get('idx', x.get('frame', 0))))
    frames = []
    for frame in data_sorted:
        kpts = np.array(frame['keypoints']).reshape(-1, 3)  # (17, 3)
        xy = kpts[:, :2].flatten()  # (34,)
        frames.append(xy)
    return np.array(frames)  # (T, 34)

def extract_gait_cycle(pose, joint_index=15, min_distance=20, smooth_window=9):
    """
    Detect gait cycles using y-coordinate of specified ankle (15=left, 16=right).
    Returns: cycles (list of arrays), peaks (int indices), y_smooth (for viz)
    """
    y_signal = pose[:, joint_index * 2 + 1]

    if len(y_signal) < 3 or np.all(np.isnan(y_signal)):
        return [], np.array([], dtype=int), y_signal

    # Safe Savitzky-Golay window
    max_win = len(y_signal) if len(y_signal) % 2 == 1 else len(y_signal) - 1
    win = min(smooth_window, max_win)
    if win < 3:
        win = 3
    if win % 2 == 0:
        win += 1

    try:
        y_smooth = savgol_filter(y_signal, win, polyorder=2)
    except Exception:
        y_smooth = y_signal.copy()

    prominence = max(1e-3, np.nanstd(y_smooth) * 0.2) if not np.all(np.isnan(y_smooth)) else 1e-3
    peaks, _ = find_peaks(y_smooth, distance=min_distance, prominence=prominence)
    peaks = np.array(peaks, dtype=int)

    # No fallback here — let caller handle joint switching
    if len(peaks) < 2:
        return [], peaks, y_smooth

    cycles = [pose[peaks[i]:peaks[i+1]] for i in range(len(peaks) - 1)]
    return cycles, peaks, y_smooth

def to_py(o):
    if isinstance(o, np.ndarray):
        return o.tolist()
    if isinstance(o, (np.integer, np.floating)):
        return o.item()
    if isinstance(o, list):
        return [to_py(x) for x in o]
    if isinstance(o, dict):
        return {k: to_py(v) for k, v in o.items()}
    return o

# %%
# DIAGNOSTIC: Check discovered files before processing
json_files = sorted(JSON_DIR.rglob("*.json"))
print(f"Found {len(json_files)} JSON files in online_dataset.\n")

# Count by label
np_files = [f for f in json_files if infer_label(f) == '0']
pd_files = [f for f in json_files if infer_label(f) == '1']
unk_files = [f for f in json_files if infer_label(f) == 'UNK']

print("File distribution by label:")
print(f"  NP (label 0): {len(np_files)} files")
print(f"  PD (label 1): {len(pd_files)} files")
print(f"  Unknown: {len(unk_files)} files")

if len(np_files) > 0:
    print(f"\nFirst 3 NP files:")
    for f in np_files[:3]:
        print(f"  {f.relative_to(JSON_DIR)}")
        
if len(pd_files) > 0:
    print(f"\nFirst 3 PD files:")
    for f in pd_files[:3]:
        print(f"  {f.relative_to(JSON_DIR)}")

print(f"\n{'='*60}")
print("Starting data extraction...")
print(f"{'='*60}")
# Out:
# Found 280 JSON files in online_dataset.
#
# File distribution by label:
#   NP (label 0): 140 files
#   PD (label 1): 140 files
#   Unknown: 0 files
#
# First 3 NP files:
#   NP\normal_1\alphapose-results.json
#   NP\normal_10\alphapose-results.json
#   NP\normal_100\alphapose-results.json
#
# First 3 PD files:
#   PD\Mild\mild_youtube_03032022_06.mp4\alphapose-results.json
#   PD\Mild\mild_youtube_03032022_10.mp4\alphapose-results.json
#   PD\Mild\mild_youtube_10012022_1.mp4\alphapose-results.json
#
# ============================================================
# Starting data extraction...
# ============================================================

# %%
metadata = []

# Recursively find all JSON files in NP/ and PD/ subdirectories
json_files = sorted(JSON_DIR.rglob("*.json"))

for json_path in json_files:
    relative_path = json_path.relative_to(JSON_DIR)
    # Create unique file_id using folder structure + filename
    # e.g., "PD/Mild/subject1/alphapose-results.json" → "PD_Mild_subject1_alphapose-results"
    file_id = str(relative_path.with_suffix('')).replace('\\', '_').replace('/', '_')
    print(f"\n{relative_path} → {file_id}")
    
    # 1. Load data
    try:
        xy_seq = load_alphapose_json(json_path)
        T = xy_seq.shape[0]
        print(f"  Loaded {T} frames")
        if T == 0:
            xy_seq = np.zeros((60, 34), dtype=np.float32)  # dummy sequence
            T = 60
    except Exception as e:
        print(f" Load error → using dummy: {e}")
        xy_seq = np.zeros((60, 34), dtype=np.float32)
        T = 60

    # 2. Try gait cycle extraction (ankles → knees → fallback)
    cycles = []
    used_method = "fallback_uniform"
    
    # Try ankles (15, 16)
    for joint_idx, name in [(15, "left_ankle"), (16, "right_ankle")]:
        try:
            c, p, _ = extract_gait_cycle(xy_seq, joint_index=joint_idx, min_distance=20)
            if len(c) >= 1:
                cycles = c
                peaks = p
                used_method = f"{name} ({len(c)} cycles)"
                break
        except Exception as e:
            print(f"    {name} failed: {e}")
    
    # Try knees if ankles failed
    if len(cycles) == 0:
        for joint_idx, name in [(13, "left_knee"), (14, "right_knee")]:
            try:
                c, p, _ = extract_gait_cycle(xy_seq, joint_index=joint_idx, min_distance=20)
                if len(c) >= 1:
                    cycles = c
                    peaks = p
                    used_method = f"{name} ({len(c)} cycles)"
                    break
            except Exception as e:
                print(f"    {name} failed: {e}")
    
    # uniform segmentation (guaranteed 6 cycles)
    if len(cycles) == 0:
        print(f" All joint-based detection failed → using uniform segmentation")
        cycle_len = max(1, T // 6)
        cycles = []
        peaks = []
        for i in range(6):
            start = i * cycle_len
            end = min((i + 1) * cycle_len, T)
            if start >= T:
                break
            cyc = xy_seq[start:end]
            if len(cyc) == 0:
                cyc = xy_seq[-1:]  # repeat last frame
            cycles.append(cyc)
            peaks.append(start)
        peaks.append(T)  # final peak
        peaks = np.array(peaks[:7])  # ensure 7 peaks
        used_method = "uniform_segmentation"
    
    # At this point, cycles is non-empty (may be <6)
    detected = len(cycles)
    print(f"  → Detected {detected} cycles ({used_method})")

    # 3. Enforce exactly 6 cycles
    original_cycle_count = detected
    if detected < 6:
        print(f"  Padding {6 - detected} cycles (repeating last valid cycle)")
        if detected == 0:
            # All else failed → create 6 dummy cycles
            dummy_cycle = np.zeros((30, 34), dtype=np.float32)
            cycles = [dummy_cycle.copy() for _ in range(6)]
            peaks = np.linspace(0, 180, 7).astype(int)  # dummy peaks
        else:
            last_cycle = cycles[-1].copy()
            while len(cycles) < 6:
                cycles.append(last_cycle.copy())
    elif detected > 6:
        cycles = cycles[:6]
        peaks = peaks[:7] if len(peaks) >= 7 else np.linspace(0, T, 7).astype(int)

    # Ensure peaks has exactly 7 values
    if len(peaks) < 7:
        if detected > 0 and 'peaks' in locals() and len(peaks) >= 2:
            avg_cycle_len = int(np.mean(np.diff(peaks)))
            while len(peaks) < 7:
                peaks = np.append(peaks, peaks[-1] + avg_cycle_len)
        else:
            peaks = np.linspace(0, T, 7).astype(int)
    peaks = peaks[:7]

    # 4. Save cycles & metadata (guaranteed 6)
    cycle_objs = []
    for i, cyc in enumerate(cycles[:6]):
        start_f = int(peaks[i])
        end_f = int(peaks[i+1]) if i+1 < len(peaks) else int(peaks[-1])
        is_padded = (i >= original_cycle_count)

        data = {
            'file_id': file_id,
            'cycle_id': i + 1,
            'start_frame': start_f,
            'end_frame': end_f,
            'n_frames_raw': len(cyc),
            'is_padded': is_padded,
            'xy': to_py(cyc)
        }
        cycle_objs.append(data)

        # Save JSON
        json_path_out = CYCLES_DIR / f"{file_id}_cycle_{i+1}.json"
        with open(json_path_out, 'w', encoding='utf-8') as f:
            json.dump(to_py(data), f, ensure_ascii=False, indent=2)

        # Metadata - now includes folder path info
        metadata.append({
            'file_id': file_id,
            'cycle_id': i + 1,
            'start_frame': start_f,
            'end_frame': end_f,
            'n_frames_raw': len(cyc),
            'is_padded': is_padded,
            'detected_using': used_method,
            'original_cycle_count': original_cycle_count,
            'label': infer_label(json_path),
            'severity': infer_severity(json_path),
            'source': str(relative_path),
            'folder': str(relative_path.parent)
        })

    # Save grouped cycles (1 to 6) — PREFIX-BASED (1), (1+2), (1+2+3), ..., (1-6)
    def save_group(n, chunk):
        cids = [c['cycle_id'] for c in chunk]
        combined_xy = np.concatenate([np.asarray(c['xy']) for c in chunk], axis=0)
        out = {
            'file_id': file_id,
            'group_size': n,
            'cycle_ids': cids,
            'start_cycle': cids[0],
            'end_cycle': cids[-1],
            'n_frames_raw': len(combined_xy),
            'xy': to_py(combined_xy)
        }
        fname = f"{file_id}_{n}cycle_1-{n}.json"  # e.g., PD_01_3cycle_1-3.json
        with open(GROUPS_DIR / fname, 'w', encoding='utf-8') as f:
            json.dump(to_py(out), f, ensure_ascii=False, indent=2)

    # Generate cumulative groupings: 1-cycle, 1-2, 1-3, ..., 1-6
    for n in range(1, 7):
        chunk = cycle_objs[:n]  # First n cycles only
        save_group(n, chunk)

    print(f" Saved 6 cycles + {sum(6//n for n in range(1,7))} groups")

# 5. Final save
if metadata:
    meta_df = pd.DataFrame(metadata)
    # Ensure all file_ids have exactly 6 cycles
    cycle_counts = meta_df['file_id'].value_counts()
    # Validate 6 cycles per unique source (path), since file_id repeats
    cycle_counts = meta_df.groupby('source')['cycle_id'].count()
    assert cycle_counts.eq(6).all(), f"Some files don't have 6 cycles: {cycle_counts[cycle_counts != 6]}"
    
    meta_df.to_csv(METADATA_PATH, index=False)
    print(f"\nMetadata saved: {METADATA_PATH}")
    print(f"   Total unique files: {meta_df['file_id'].nunique()}")
    print(f"   Total cycles: {len(meta_df)} (6 per file)")
    print(f"\nLabel distribution:")
    print(meta_df.groupby('label')['file_id'].nunique())
    if 'severity' in meta_df.columns:
        print(f"\nSeverity distribution (PD only):")
        print(meta_df[meta_df['label'] == '1'].groupby('severity')['file_id'].nunique())
else:
    raise RuntimeError("No metadata generated — all files failed!")
# Out:
# NP\normal_1\alphapose-results.json → NP_normal_1_alphapose-results
#   Loaded 187 frames
#   → Detected 4 cycles (left_ankle (4 cycles))
#   Padding 2 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_10\alphapose-results.json → NP_normal_10_alphapose-results
#   Loaded 429 frames
#   → Detected 15 cycles (left_ankle (15 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_100\alphapose-results.json → NP_normal_100_alphapose-results
#   Loaded 179 frames
#   → Detected 2 cycles (left_ankle (2 cycles))
#   Padding 4 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_101\alphapose-results.json → NP_normal_101_alphapose-results
#   Loaded 184 frames
#   → Detected 5 cycles (left_ankle (5 cycles))
#   Padding 1 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_102\alphapose-results.json → NP_normal_102_alphapose-results
#   Loaded 352 frames
#   → Detected 13 cycles (left_ankle (13 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_103\alphapose-results.json → NP_normal_103_alphapose-results
#   Loaded 260 frames
#   → Detected 8 cycles (left_ankle (8 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_104\alphapose-results.json → NP_normal_104_alphapose-results
#   Loaded 225 frames
#   → Detected 7 cycles (left_ankle (7 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_105\alphapose-results.json → NP_normal_105_alphapose-results
#   Loaded 178 frames
#   → Detected 6 cycles (left_ankle (6 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_106\alphapose-results.json → NP_normal_106_alphapose-results
#   Loaded 435 frames
#   → Detected 15 cycles (left_ankle (15 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_107\alphapose-results.json → NP_normal_107_alphapose-results
#   Loaded 264 frames
#   → Detected 8 cycles (left_ankle (8 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_108\alphapose-results.json → NP_normal_108_alphapose-results
#   Loaded 250 frames
#   → Detected 8 cycles (left_ankle (8 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_109\alphapose-results.json → NP_normal_109_alphapose-results
#   Loaded 232 frames
#   → Detected 7 cycles (left_ankle (7 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_11\alphapose-results.json → NP_normal_11_alphapose-results
#   Loaded 288 frames
#   → Detected 7 cycles (left_ankle (7 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_110\alphapose-results.json → NP_normal_110_alphapose-results
#   Loaded 324 frames
#   → Detected 10 cycles (left_ankle (10 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_111\alphapose-results.json → NP_normal_111_alphapose-results
#   Loaded 252 frames
#   → Detected 6 cycles (left_ankle (6 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_112\alphapose-results.json → NP_normal_112_alphapose-results
#   Loaded 241 frames
#   → Detected 8 cycles (left_ankle (8 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_113\alphapose-results.json → NP_normal_113_alphapose-results
#   Loaded 320 frames
#   → Detected 9 cycles (left_ankle (9 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_114\alphapose-results.json → NP_normal_114_alphapose-results
#   Loaded 275 frames
#   → Detected 6 cycles (left_ankle (6 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_115\alphapose-results.json → NP_normal_115_alphapose-results
#   Loaded 550 frames
#   → Detected 13 cycles (left_ankle (13 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_116\alphapose-results.json → NP_normal_116_alphapose-results
#   Loaded 485 frames
#   → Detected 18 cycles (left_ankle (18 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_117\alphapose-results.json → NP_normal_117_alphapose-results
#   Loaded 208 frames
#   → Detected 3 cycles (left_ankle (3 cycles))
#   Padding 3 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_118\alphapose-results.json → NP_normal_118_alphapose-results
#   Loaded 191 frames
#   → Detected 3 cycles (left_ankle (3 cycles))
#   Padding 3 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_119\alphapose-results.json → NP_normal_119_alphapose-results
#   Loaded 446 frames
#   → Detected 13 cycles (left_ankle (13 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_12\alphapose-results.json → NP_normal_12_alphapose-results
#   Loaded 237 frames
#   → Detected 6 cycles (left_ankle (6 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_120\alphapose-results.json → NP_normal_120_alphapose-results
#   Loaded 229 frames
#   → Detected 4 cycles (left_ankle (4 cycles))
#   Padding 2 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_121\alphapose-results.json → NP_normal_121_alphapose-results
#   Loaded 414 frames
#   → Detected 13 cycles (left_ankle (13 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_122\alphapose-results.json → NP_normal_122_alphapose-results
#   Loaded 385 frames
#   → Detected 11 cycles (left_ankle (11 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_123\alphapose-results.json → NP_normal_123_alphapose-results
#   Loaded 168 frames
#   → Detected 3 cycles (left_ankle (3 cycles))
#   Padding 3 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_124\alphapose-results.json → NP_normal_124_alphapose-results
#   Loaded 3122 frames
#   → Detected 117 cycles (left_ankle (117 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_125\alphapose-results.json → NP_normal_125_alphapose-results
#   Loaded 921 frames
#   → Detected 34 cycles (left_ankle (34 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_126\alphapose-results.json → NP_normal_126_alphapose-results
#   Loaded 546 frames
#   → Detected 18 cycles (left_ankle (18 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_127\alphapose-results.json → NP_normal_127_alphapose-results
#   Loaded 1336 frames
#   → Detected 41 cycles (left_ankle (41 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_128\alphapose-results.json → NP_normal_128_alphapose-results
#   Loaded 1473 frames
#   → Detected 51 cycles (left_ankle (51 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_129\alphapose-results.json → NP_normal_129_alphapose-results
#   Loaded 932 frames
#   → Detected 17 cycles (left_ankle (17 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_13\alphapose-results.json → NP_normal_13_alphapose-results
#   Loaded 221 frames
#   → Detected 5 cycles (left_ankle (5 cycles))
#   Padding 1 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_130\alphapose-results.json → NP_normal_130_alphapose-results
#   Loaded 1412 frames
#   → Detected 48 cycles (left_ankle (48 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_131\alphapose-results.json → NP_normal_131_alphapose-results
#   Loaded 388 frames
#   → Detected 9 cycles (left_ankle (9 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_132\alphapose-results.json → NP_normal_132_alphapose-results
#   Loaded 176 frames
#   → Detected 4 cycles (left_ankle (4 cycles))
#   Padding 2 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_133\alphapose-results.json → NP_normal_133_alphapose-results
#   Loaded 623 frames
#   → Detected 21 cycles (left_ankle (21 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_134\alphapose-results.json → NP_normal_134_alphapose-results
#   Loaded 615 frames
#   → Detected 20 cycles (left_ankle (20 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_135\alphapose-results.json → NP_normal_135_alphapose-results
#   Loaded 253 frames
#   → Detected 8 cycles (left_ankle (8 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_136\alphapose-results.json → NP_normal_136_alphapose-results
#   Loaded 1145 frames
#   → Detected 32 cycles (left_ankle (32 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_137\alphapose-results.json → NP_normal_137_alphapose-results
#   Loaded 1192 frames
#   → Detected 43 cycles (left_ankle (43 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_138\alphapose-results.json → NP_normal_138_alphapose-results
#   Loaded 1310 frames
#   → Detected 40 cycles (left_ankle (40 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_139\alphapose-results.json → NP_normal_139_alphapose-results
#   Loaded 301 frames
#   → Detected 9 cycles (left_ankle (9 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_14\alphapose-results.json → NP_normal_14_alphapose-results
#   Loaded 281 frames
#   → Detected 10 cycles (left_ankle (10 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_140\alphapose-results.json → NP_normal_140_alphapose-results
#   Loaded 276 frames
#   → Detected 5 cycles (left_ankle (5 cycles))
#   Padding 1 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_15\alphapose-results.json → NP_normal_15_alphapose-results
#   Loaded 183 frames
#   → Detected 5 cycles (left_ankle (5 cycles))
#   Padding 1 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_16\alphapose-results.json → NP_normal_16_alphapose-results
#   Loaded 711 frames
#   → Detected 25 cycles (left_ankle (25 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_17\alphapose-results.json → NP_normal_17_alphapose-results
#   Loaded 276 frames
#   → Detected 7 cycles (left_ankle (7 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_18\alphapose-results.json → NP_normal_18_alphapose-results
#   Loaded 203 frames
#   → Detected 5 cycles (left_ankle (5 cycles))
#   Padding 1 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_19\alphapose-results.json → NP_normal_19_alphapose-results
#   Loaded 180 frames
#   → Detected 3 cycles (left_ankle (3 cycles))
#   Padding 3 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_2\alphapose-results.json → NP_normal_2_alphapose-results
#   Loaded 193 frames
#   → Detected 6 cycles (left_ankle (6 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_20\alphapose-results.json → NP_normal_20_alphapose-results
#   Loaded 332 frames
#   → Detected 10 cycles (left_ankle (10 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_21\alphapose-results.json → NP_normal_21_alphapose-results
#   Loaded 331 frames
#   → Detected 10 cycles (left_ankle (10 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_22\alphapose-results.json → NP_normal_22_alphapose-results
#   Loaded 251 frames
#   → Detected 5 cycles (left_ankle (5 cycles))
#   Padding 1 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_23\alphapose-results.json → NP_normal_23_alphapose-results
#   Loaded 238 frames
#   → Detected 9 cycles (left_ankle (9 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_24\alphapose-results.json → NP_normal_24_alphapose-results
#   Loaded 187 frames
#   → Detected 5 cycles (left_ankle (5 cycles))
#   Padding 1 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_25\alphapose-results.json → NP_normal_25_alphapose-results
#   Loaded 279 frames
#   → Detected 8 cycles (left_ankle (8 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_26\alphapose-results.json → NP_normal_26_alphapose-results
#   Loaded 340 frames
#   → Detected 10 cycles (left_ankle (10 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_27\alphapose-results.json → NP_normal_27_alphapose-results
#   Loaded 234 frames
#   → Detected 8 cycles (left_ankle (8 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_28\alphapose-results.json → NP_normal_28_alphapose-results
#   Loaded 269 frames
#   → Detected 10 cycles (left_ankle (10 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_29\alphapose-results.json → NP_normal_29_alphapose-results
#   Loaded 215 frames
#   → Detected 8 cycles (left_ankle (8 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_3\alphapose-results.json → NP_normal_3_alphapose-results
#   Loaded 232 frames
#   → Detected 6 cycles (left_ankle (6 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_30\alphapose-results.json → NP_normal_30_alphapose-results
#   Loaded 390 frames
#   → Detected 13 cycles (left_ankle (13 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_31\alphapose-results.json → NP_normal_31_alphapose-results
#   Loaded 351 frames
#   → Detected 11 cycles (left_ankle (11 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_32\alphapose-results.json → NP_normal_32_alphapose-results
#   Loaded 405 frames
#   → Detected 12 cycles (left_ankle (12 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_33\alphapose-results.json → NP_normal_33_alphapose-results
#   Loaded 393 frames
#   → Detected 12 cycles (left_ankle (12 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_34\alphapose-results.json → NP_normal_34_alphapose-results
#   Loaded 154 frames
#   → Detected 2 cycles (left_ankle (2 cycles))
#   Padding 4 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_35\alphapose-results.json → NP_normal_35_alphapose-results
#   Loaded 102 frames
#   → Detected 2 cycles (left_ankle (2 cycles))
#   Padding 4 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_36\alphapose-results.json → NP_normal_36_alphapose-results
#   Loaded 247 frames
#   → Detected 6 cycles (left_ankle (6 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_37\alphapose-results.json → NP_normal_37_alphapose-results
#   Loaded 201 frames
#   → Detected 6 cycles (left_ankle (6 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_38\alphapose-results.json → NP_normal_38_alphapose-results
#   Loaded 266 frames
#   → Detected 5 cycles (left_ankle (5 cycles))
#   Padding 1 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_39\alphapose-results.json → NP_normal_39_alphapose-results
#   Loaded 339 frames
#   → Detected 9 cycles (left_ankle (9 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_4\alphapose-results.json → NP_normal_4_alphapose-results
#   Loaded 279 frames
#   → Detected 8 cycles (left_ankle (8 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_40\alphapose-results.json → NP_normal_40_alphapose-results
#   Loaded 381 frames
#   → Detected 11 cycles (left_ankle (11 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_41\alphapose-results.json → NP_normal_41_alphapose-results
#   Loaded 226 frames
#   → Detected 7 cycles (left_ankle (7 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_42\alphapose-results.json → NP_normal_42_alphapose-results
#   Loaded 245 frames
#   → Detected 7 cycles (left_ankle (7 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_43\alphapose-results.json → NP_normal_43_alphapose-results
#   Loaded 240 frames
#   → Detected 6 cycles (left_ankle (6 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_44\alphapose-results.json → NP_normal_44_alphapose-results
#   Loaded 320 frames
#   → Detected 10 cycles (left_ankle (10 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_45\alphapose-results.json → NP_normal_45_alphapose-results
#   Loaded 868 frames
#   → Detected 32 cycles (left_ankle (32 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_46\alphapose-results.json → NP_normal_46_alphapose-results
#   Loaded 278 frames
#   → Detected 6 cycles (left_ankle (6 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_47\alphapose-results.json → NP_normal_47_alphapose-results
#   Loaded 158 frames
#   → Detected 4 cycles (left_ankle (4 cycles))
#   Padding 2 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_48\alphapose-results.json → NP_normal_48_alphapose-results
#   Loaded 234 frames
#   → Detected 6 cycles (left_ankle (6 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_49\alphapose-results.json → NP_normal_49_alphapose-results
#   Loaded 186 frames
#   → Detected 6 cycles (left_ankle (6 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_5\alphapose-results.json → NP_normal_5_alphapose-results
#   Loaded 290 frames
#   → Detected 10 cycles (left_ankle (10 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_50\alphapose-results.json → NP_normal_50_alphapose-results
#   Loaded 648 frames
#   → Detected 21 cycles (left_ankle (21 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_51\alphapose-results.json → NP_normal_51_alphapose-results
#   Loaded 596 frames
#   → Detected 18 cycles (left_ankle (18 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_52\alphapose-results.json → NP_normal_52_alphapose-results
#   Loaded 210 frames
#   → Detected 6 cycles (left_ankle (6 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_53\alphapose-results.json → NP_normal_53_alphapose-results
#   Loaded 324 frames
#   → Detected 9 cycles (left_ankle (9 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_54\alphapose-results.json → NP_normal_54_alphapose-results
#   Loaded 324 frames
#   → Detected 7 cycles (left_ankle (7 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_55\alphapose-results.json → NP_normal_55_alphapose-results
#   Loaded 230 frames
#   → Detected 6 cycles (left_ankle (6 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_56\alphapose-results.json → NP_normal_56_alphapose-results
#   Loaded 339 frames
#   → Detected 11 cycles (left_ankle (11 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_57\alphapose-results.json → NP_normal_57_alphapose-results
#   Loaded 219 frames
#   → Detected 6 cycles (left_ankle (6 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_58\alphapose-results.json → NP_normal_58_alphapose-results
#   Loaded 507 frames
#   → Detected 18 cycles (left_ankle (18 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_59\alphapose-results.json → NP_normal_59_alphapose-results
#   Loaded 306 frames
#   → Detected 11 cycles (left_ankle (11 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_6\alphapose-results.json → NP_normal_6_alphapose-results
#   Loaded 187 frames
#   → Detected 4 cycles (left_ankle (4 cycles))
#   Padding 2 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_60\alphapose-results.json → NP_normal_60_alphapose-results
#   Loaded 188 frames
#   → Detected 6 cycles (left_ankle (6 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_61\alphapose-results.json → NP_normal_61_alphapose-results
#   Loaded 453 frames
#   → Detected 15 cycles (left_ankle (15 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_62\alphapose-results.json → NP_normal_62_alphapose-results
#   Loaded 196 frames
#   → Detected 4 cycles (left_ankle (4 cycles))
#   Padding 2 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_63\alphapose-results.json → NP_normal_63_alphapose-results
#   Loaded 245 frames
#   → Detected 6 cycles (left_ankle (6 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_64\alphapose-results.json → NP_normal_64_alphapose-results
#   Loaded 234 frames
#   → Detected 8 cycles (left_ankle (8 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_65\alphapose-results.json → NP_normal_65_alphapose-results
#   Loaded 241 frames
#   → Detected 9 cycles (left_ankle (9 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_66\alphapose-results.json → NP_normal_66_alphapose-results
#   Loaded 274 frames
#   → Detected 7 cycles (left_ankle (7 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_67\alphapose-results.json → NP_normal_67_alphapose-results
#   Loaded 547 frames
#   → Detected 19 cycles (left_ankle (19 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_68\alphapose-results.json → NP_normal_68_alphapose-results
#   Loaded 504 frames
#   → Detected 19 cycles (left_ankle (19 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_69\alphapose-results.json → NP_normal_69_alphapose-results
#   Loaded 299 frames
#   → Detected 8 cycles (left_ankle (8 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_7\alphapose-results.json → NP_normal_7_alphapose-results
#   Loaded 206 frames
#   → Detected 5 cycles (left_ankle (5 cycles))
#   Padding 1 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_70\alphapose-results.json → NP_normal_70_alphapose-results
#   Loaded 278 frames
#   → Detected 7 cycles (left_ankle (7 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_71\alphapose-results.json → NP_normal_71_alphapose-results
#   Loaded 225 frames
#   → Detected 6 cycles (left_ankle (6 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_72\alphapose-results.json → NP_normal_72_alphapose-results
#   Loaded 703 frames
#   → Detected 25 cycles (left_ankle (25 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_73\alphapose-results.json → NP_normal_73_alphapose-results
#   Loaded 156 frames
#   → Detected 4 cycles (left_ankle (4 cycles))
#   Padding 2 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_74\alphapose-results.json → NP_normal_74_alphapose-results
#   Loaded 234 frames
#   → Detected 7 cycles (left_ankle (7 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_75\alphapose-results.json → NP_normal_75_alphapose-results
#   Loaded 190 frames
#   → Detected 6 cycles (left_ankle (6 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_76\alphapose-results.json → NP_normal_76_alphapose-results
#   Loaded 492 frames
#   → Detected 17 cycles (left_ankle (17 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_77\alphapose-results.json → NP_normal_77_alphapose-results
#   Loaded 164 frames
#   → Detected 3 cycles (left_ankle (3 cycles))
#   Padding 3 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_78\alphapose-results.json → NP_normal_78_alphapose-results
#   Loaded 196 frames
#   → Detected 5 cycles (left_ankle (5 cycles))
#   Padding 1 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_79\alphapose-results.json → NP_normal_79_alphapose-results
#   Loaded 303 frames
#   → Detected 10 cycles (left_ankle (10 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_8\alphapose-results.json → NP_normal_8_alphapose-results
#   Loaded 351 frames
#   → Detected 9 cycles (left_ankle (9 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_80\alphapose-results.json → NP_normal_80_alphapose-results
#   Loaded 259 frames
#   → Detected 8 cycles (left_ankle (8 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_81\alphapose-results.json → NP_normal_81_alphapose-results
#   Loaded 477 frames
#   → Detected 15 cycles (left_ankle (15 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_82\alphapose-results.json → NP_normal_82_alphapose-results
#   Loaded 274 frames
#   → Detected 5 cycles (left_ankle (5 cycles))
#   Padding 1 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_83\alphapose-results.json → NP_normal_83_alphapose-results
#   Loaded 394 frames
#   → Detected 12 cycles (left_ankle (12 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_84\alphapose-results.json → NP_normal_84_alphapose-results
#   Loaded 205 frames
#   → Detected 6 cycles (left_ankle (6 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_85\alphapose-results.json → NP_normal_85_alphapose-results
#   Loaded 214 frames
#   → Detected 7 cycles (left_ankle (7 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_86\alphapose-results.json → NP_normal_86_alphapose-results
#   Loaded 201 frames
#   → Detected 4 cycles (left_ankle (4 cycles))
#   Padding 2 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_87\alphapose-results.json → NP_normal_87_alphapose-results
#   Loaded 168 frames
#   → Detected 5 cycles (left_ankle (5 cycles))
#   Padding 1 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_88\alphapose-results.json → NP_normal_88_alphapose-results
#   Loaded 326 frames
#   → Detected 7 cycles (left_ankle (7 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_89\alphapose-results.json → NP_normal_89_alphapose-results
#   Loaded 221 frames
#   → Detected 6 cycles (left_ankle (6 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_9\alphapose-results.json → NP_normal_9_alphapose-results
#   Loaded 535 frames
#   → Detected 13 cycles (left_ankle (13 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_90\alphapose-results.json → NP_normal_90_alphapose-results
#   Loaded 640 frames
#   → Detected 19 cycles (left_ankle (19 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_91\alphapose-results.json → NP_normal_91_alphapose-results
#   Loaded 213 frames
#   → Detected 5 cycles (left_ankle (5 cycles))
#   Padding 1 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_92\alphapose-results.json → NP_normal_92_alphapose-results
#   Loaded 223 frames
#   → Detected 7 cycles (left_ankle (7 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_93\alphapose-results.json → NP_normal_93_alphapose-results
#   Loaded 214 frames
#   → Detected 4 cycles (left_ankle (4 cycles))
#   Padding 2 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_94\alphapose-results.json → NP_normal_94_alphapose-results
#   Loaded 223 frames
#   → Detected 7 cycles (left_ankle (7 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_95\alphapose-results.json → NP_normal_95_alphapose-results
#   Loaded 167 frames
#   → Detected 5 cycles (left_ankle (5 cycles))
#   Padding 1 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_96\alphapose-results.json → NP_normal_96_alphapose-results
#   Loaded 216 frames
#   → Detected 6 cycles (left_ankle (6 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_97\alphapose-results.json → NP_normal_97_alphapose-results
#   Loaded 169 frames
#   → Detected 3 cycles (left_ankle (3 cycles))
#   Padding 3 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# NP\normal_98\alphapose-results.json → NP_normal_98_alphapose-results
#   Loaded 227 frames
#   → Detected 6 cycles (left_ankle (6 cycles))
#  Saved 6 cycles + 14 groups
#
# NP\normal_99\alphapose-results.json → NP_normal_99_alphapose-results
#   Loaded 184 frames
#   → Detected 6 cycles (left_ankle (6 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_03032022_06.mp4\alphapose-results.json → PD_Mild_mild_youtube_03032022_06.mp4_alphapose-results
#   Loaded 128 frames
#   → Detected 3 cycles (left_ankle (3 cycles))
#   Padding 3 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_03032022_10.mp4\alphapose-results.json → PD_Mild_mild_youtube_03032022_10.mp4_alphapose-results
#   Loaded 260 frames
#   → Detected 9 cycles (left_ankle (9 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_10012022_1.mp4\alphapose-results.json → PD_Mild_mild_youtube_10012022_1.mp4_alphapose-results
#   Loaded 212 frames
#   → Detected 5 cycles (left_ankle (5 cycles))
#   Padding 1 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_11122021_2.mp4\alphapose-results.json → PD_Mild_mild_youtube_11122021_2.mp4_alphapose-results
#   Loaded 505 frames
#   → Detected 11 cycles (left_ankle (11 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_11122021_3.mp4\alphapose-results.json → PD_Mild_mild_youtube_11122021_3.mp4_alphapose-results
#   Loaded 509 frames
#   → Detected 13 cycles (left_ankle (13 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_12122021_1.mp4\alphapose-results.json → PD_Mild_mild_youtube_12122021_1.mp4_alphapose-results
#   Loaded 122 frames
#   → Detected 3 cycles (left_ankle (3 cycles))
#   Padding 3 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_12122021_2.mp4\alphapose-results.json → PD_Mild_mild_youtube_12122021_2.mp4_alphapose-results
#   Loaded 164 frames
#   → Detected 4 cycles (left_ankle (4 cycles))
#   Padding 2 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_13122021_5.mp4\alphapose-results.json → PD_Mild_mild_youtube_13122021_5.mp4_alphapose-results
#   Loaded 357 frames
#   → Detected 10 cycles (left_ankle (10 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_18122021_4.mp4\alphapose-results.json → PD_Mild_mild_youtube_18122021_4.mp4_alphapose-results
#   Loaded 398 frames
#   → Detected 10 cycles (left_ankle (10 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_18122021_5.mp4\alphapose-results.json → PD_Mild_mild_youtube_18122021_5.mp4_alphapose-results
#   Loaded 359 frames
#   → Detected 10 cycles (left_ankle (10 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_19032022_16.mp4\alphapose-results.json → PD_Mild_mild_youtube_19032022_16.mp4_alphapose-results
#   Loaded 276 frames
#   → Detected 8 cycles (left_ankle (8 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_19122021_3.mp4\alphapose-results.json → PD_Mild_mild_youtube_19122021_3.mp4_alphapose-results
#   Loaded 1010 frames
#   → Detected 26 cycles (left_ankle (26 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_20012022_4.mp4\alphapose-results.json → PD_Mild_mild_youtube_20012022_4.mp4_alphapose-results
#   Loaded 252 frames
#   → Detected 8 cycles (left_ankle (8 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_22012022_2.mp4\alphapose-results.json → PD_Mild_mild_youtube_22012022_2.mp4_alphapose-results
#   Loaded 415 frames
#   → Detected 16 cycles (left_ankle (16 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_22012022_5.mp4\alphapose-results.json → PD_Mild_mild_youtube_22012022_5.mp4_alphapose-results
#   Loaded 354 frames
#   → Detected 12 cycles (left_ankle (12 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_23022022_02.mp4\alphapose-results.json → PD_Mild_mild_youtube_23022022_02.mp4_alphapose-results
#   Loaded 510 frames
#   → Detected 17 cycles (left_ankle (17 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_23022022_03.mp4\alphapose-results.json → PD_Mild_mild_youtube_23022022_03.mp4_alphapose-results
#   Loaded 456 frames
#   → Detected 13 cycles (left_ankle (13 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_23022022_09.mp4\alphapose-results.json → PD_Mild_mild_youtube_23022022_09.mp4_alphapose-results
#   Loaded 226 frames
#   → Detected 6 cycles (left_ankle (6 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_23022022_10.mp4\alphapose-results.json → PD_Mild_mild_youtube_23022022_10.mp4_alphapose-results
#   Loaded 209 frames
#   → Detected 7 cycles (left_ankle (7 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_23022022_11.mp4\alphapose-results.json → PD_Mild_mild_youtube_23022022_11.mp4_alphapose-results
#   Loaded 259 frames
#   → Detected 8 cycles (left_ankle (8 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_23022022_12.mp4\alphapose-results.json → PD_Mild_mild_youtube_23022022_12.mp4_alphapose-results
#   Loaded 160 frames
#   → Detected 4 cycles (left_ankle (4 cycles))
#   Padding 2 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_23022022_15.mp4\alphapose-results.json → PD_Mild_mild_youtube_23022022_15.mp4_alphapose-results
#   Loaded 571 frames
#   → Detected 16 cycles (left_ankle (16 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_23022022_17.mp4\alphapose-results.json → PD_Mild_mild_youtube_23022022_17.mp4_alphapose-results
#   Loaded 156 frames
#   → Detected 5 cycles (left_ankle (5 cycles))
#   Padding 1 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_23022022_20.mp4\alphapose-results.json → PD_Mild_mild_youtube_23022022_20.mp4_alphapose-results
#   Loaded 322 frames
#   → Detected 7 cycles (left_ankle (7 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_23022022_21.mp4\alphapose-results.json → PD_Mild_mild_youtube_23022022_21.mp4_alphapose-results
#   Loaded 503 frames
#   → Detected 16 cycles (left_ankle (16 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_23022022_22.mp4\alphapose-results.json → PD_Mild_mild_youtube_23022022_22.mp4_alphapose-results
#   Loaded 1000 frames
#   → Detected 27 cycles (left_ankle (27 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_23022022_23.mp4\alphapose-results.json → PD_Mild_mild_youtube_23022022_23.mp4_alphapose-results
#   Loaded 460 frames
#   → Detected 13 cycles (left_ankle (13 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_23022022_26.mp4\alphapose-results.json → PD_Mild_mild_youtube_23022022_26.mp4_alphapose-results
#   Loaded 399 frames
#   → Detected 16 cycles (left_ankle (16 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_23022022_27.mp4\alphapose-results.json → PD_Mild_mild_youtube_23022022_27.mp4_alphapose-results
#   Loaded 394 frames
#   → Detected 13 cycles (left_ankle (13 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_24012022_6.mp4\alphapose-results.json → PD_Mild_mild_youtube_24012022_6.mp4_alphapose-results
#   Loaded 827 frames
#   → Detected 27 cycles (left_ankle (27 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Mild\mild_youtube_24012022_7.mp4\alphapose-results.json → PD_Mild_mild_youtube_24012022_7.mp4_alphapose-results
#   Loaded 469 frames
#   → Detected 14 cycles (left_ankle (14 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_1\alphapose-results.json → PD_Moderate_moderate_1_alphapose-results
#   Loaded 363 frames
#   → Detected 11 cycles (left_ankle (11 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_10\alphapose-results.json → PD_Moderate_moderate_10_alphapose-results
#   Loaded 739 frames
#   → Detected 21 cycles (left_ankle (21 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_11\alphapose-results.json → PD_Moderate_moderate_11_alphapose-results
#   Loaded 757 frames
#   → Detected 27 cycles (left_ankle (27 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_12\alphapose-results.json → PD_Moderate_moderate_12_alphapose-results
#   Loaded 894 frames
#   → Detected 23 cycles (left_ankle (23 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_13\alphapose-results.json → PD_Moderate_moderate_13_alphapose-results
#   Loaded 482 frames
#   → Detected 13 cycles (left_ankle (13 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_14\alphapose-results.json → PD_Moderate_moderate_14_alphapose-results
#   Loaded 230 frames
#   → Detected 7 cycles (left_ankle (7 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_15\alphapose-results.json → PD_Moderate_moderate_15_alphapose-results
#   Loaded 4088 frames
#   → Detected 150 cycles (left_ankle (150 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_16\alphapose-results.json → PD_Moderate_moderate_16_alphapose-results
#   Loaded 1908 frames
#   → Detected 62 cycles (left_ankle (62 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_17\alphapose-results.json → PD_Moderate_moderate_17_alphapose-results
#   Loaded 955 frames
#   → Detected 31 cycles (left_ankle (31 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_18\alphapose-results.json → PD_Moderate_moderate_18_alphapose-results
#   Loaded 1005 frames
#   → Detected 36 cycles (left_ankle (36 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_19\alphapose-results.json → PD_Moderate_moderate_19_alphapose-results
#   Loaded 1614 frames
#   → Detected 53 cycles (left_ankle (53 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_2\alphapose-results.json → PD_Moderate_moderate_2_alphapose-results
#   Loaded 372 frames
#   → Detected 13 cycles (left_ankle (13 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_20\alphapose-results.json → PD_Moderate_moderate_20_alphapose-results
#   Loaded 1359 frames
#   → Detected 39 cycles (left_ankle (39 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_21\alphapose-results.json → PD_Moderate_moderate_21_alphapose-results
#   Loaded 834 frames
#   → Detected 26 cycles (left_ankle (26 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_22\alphapose-results.json → PD_Moderate_moderate_22_alphapose-results
#   Loaded 1391 frames
#   → Detected 50 cycles (left_ankle (50 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_23\alphapose-results.json → PD_Moderate_moderate_23_alphapose-results
#   Loaded 954 frames
#   → Detected 32 cycles (left_ankle (32 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_24\alphapose-results.json → PD_Moderate_moderate_24_alphapose-results
#   Loaded 657 frames
#   → Detected 18 cycles (left_ankle (18 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_25\alphapose-results.json → PD_Moderate_moderate_25_alphapose-results
#   Loaded 460 frames
#   → Detected 16 cycles (left_ankle (16 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_26\alphapose-results.json → PD_Moderate_moderate_26_alphapose-results
#   Loaded 432 frames
#   → Detected 15 cycles (left_ankle (15 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_27\alphapose-results.json → PD_Moderate_moderate_27_alphapose-results
#   Loaded 410 frames
#   → Detected 14 cycles (left_ankle (14 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_28\alphapose-results.json → PD_Moderate_moderate_28_alphapose-results
#   Loaded 486 frames
#   → Detected 17 cycles (left_ankle (17 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_29\alphapose-results.json → PD_Moderate_moderate_29_alphapose-results
#   Loaded 517 frames
#   → Detected 17 cycles (left_ankle (17 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_3\alphapose-results.json → PD_Moderate_moderate_3_alphapose-results
#   Loaded 125 frames
#   → Detected 3 cycles (left_ankle (3 cycles))
#   Padding 3 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_30\alphapose-results.json → PD_Moderate_moderate_30_alphapose-results
#   Loaded 924 frames
#   → Detected 25 cycles (left_ankle (25 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_31\alphapose-results.json → PD_Moderate_moderate_31_alphapose-results
#   Loaded 195 frames
#   → Detected 4 cycles (left_ankle (4 cycles))
#   Padding 2 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_32\alphapose-results.json → PD_Moderate_moderate_32_alphapose-results
#   Loaded 631 frames
#   → Detected 21 cycles (left_ankle (21 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_33\alphapose-results.json → PD_Moderate_moderate_33_alphapose-results
#   Loaded 652 frames
#   → Detected 20 cycles (left_ankle (20 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_34\alphapose-results.json → PD_Moderate_moderate_34_alphapose-results
#   Loaded 374 frames
#   → Detected 9 cycles (left_ankle (9 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_35\alphapose-results.json → PD_Moderate_moderate_35_alphapose-results
#   Loaded 626 frames
#   → Detected 24 cycles (left_ankle (24 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_36\alphapose-results.json → PD_Moderate_moderate_36_alphapose-results
#   Loaded 418 frames
#   → Detected 11 cycles (left_ankle (11 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_37\alphapose-results.json → PD_Moderate_moderate_37_alphapose-results
#   Loaded 558 frames
#   → Detected 18 cycles (left_ankle (18 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_38\alphapose-results.json → PD_Moderate_moderate_38_alphapose-results
#   Loaded 212 frames
#   → Detected 6 cycles (left_ankle (6 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_39\alphapose-results.json → PD_Moderate_moderate_39_alphapose-results
#   Loaded 534 frames
#   → Detected 20 cycles (left_ankle (20 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_4\alphapose-results.json → PD_Moderate_moderate_4_alphapose-results
#   Loaded 727 frames
#   → Detected 27 cycles (left_ankle (27 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_40\alphapose-results.json → PD_Moderate_moderate_40_alphapose-results
#   Loaded 846 frames
#   → Detected 23 cycles (left_ankle (23 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_41\alphapose-results.json → PD_Moderate_moderate_41_alphapose-results
#   Loaded 322 frames
#   → Detected 12 cycles (left_ankle (12 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_42\alphapose-results.json → PD_Moderate_moderate_42_alphapose-results
#   Loaded 197 frames
#   → Detected 5 cycles (left_ankle (5 cycles))
#   Padding 1 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_43\alphapose-results.json → PD_Moderate_moderate_43_alphapose-results
#   Loaded 388 frames
#   → Detected 12 cycles (left_ankle (12 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_44\alphapose-results.json → PD_Moderate_moderate_44_alphapose-results
#   Loaded 237 frames
#   → Detected 7 cycles (left_ankle (7 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_45\alphapose-results.json → PD_Moderate_moderate_45_alphapose-results
#   Loaded 305 frames
#   → Detected 6 cycles (left_ankle (6 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_46\alphapose-results.json → PD_Moderate_moderate_46_alphapose-results
#   Loaded 217 frames
#   → Detected 7 cycles (left_ankle (7 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_47\alphapose-results.json → PD_Moderate_moderate_47_alphapose-results
#   Loaded 158 frames
#   → Detected 5 cycles (left_ankle (5 cycles))
#   Padding 1 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_48\alphapose-results.json → PD_Moderate_moderate_48_alphapose-results
#   Loaded 1159 frames
#   → Detected 39 cycles (left_ankle (39 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_49\alphapose-results.json → PD_Moderate_moderate_49_alphapose-results
#   Loaded 708 frames
#   → Detected 25 cycles (left_ankle (25 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_5\alphapose-results.json → PD_Moderate_moderate_5_alphapose-results
#   Loaded 314 frames
#   → Detected 8 cycles (left_ankle (8 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_50\alphapose-results.json → PD_Moderate_moderate_50_alphapose-results
#   Loaded 170 frames
#   → Detected 4 cycles (left_ankle (4 cycles))
#   Padding 2 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_51\alphapose-results.json → PD_Moderate_moderate_51_alphapose-results
#   Loaded 284 frames
#   → Detected 10 cycles (left_ankle (10 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_52\alphapose-results.json → PD_Moderate_moderate_52_alphapose-results
#   Loaded 1629 frames
#   → Detected 54 cycles (left_ankle (54 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_53\alphapose-results.json → PD_Moderate_moderate_53_alphapose-results
#   Loaded 369 frames
#   → Detected 11 cycles (left_ankle (11 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_54\alphapose-results.json → PD_Moderate_moderate_54_alphapose-results
#   Loaded 715 frames
#   → Detected 24 cycles (left_ankle (24 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_55\alphapose-results.json → PD_Moderate_moderate_55_alphapose-results
#   Loaded 257 frames
#   → Detected 8 cycles (left_ankle (8 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_56\alphapose-results.json → PD_Moderate_moderate_56_alphapose-results
#   Loaded 237 frames
#   → Detected 8 cycles (left_ankle (8 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_57\alphapose-results.json → PD_Moderate_moderate_57_alphapose-results
#   Loaded 336 frames
#   → Detected 9 cycles (left_ankle (9 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_6\alphapose-results.json → PD_Moderate_moderate_6_alphapose-results
#   Loaded 514 frames
#   → Detected 18 cycles (left_ankle (18 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_7\alphapose-results.json → PD_Moderate_moderate_7_alphapose-results
#   Loaded 563 frames
#   → Detected 18 cycles (left_ankle (18 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_8\alphapose-results.json → PD_Moderate_moderate_8_alphapose-results
#   Loaded 163 frames
#   → Detected 5 cycles (left_ankle (5 cycles))
#   Padding 1 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# PD\Moderate\moderate_9\alphapose-results.json → PD_Moderate_moderate_9_alphapose-results
#   Loaded 801 frames
#   → Detected 19 cycles (left_ankle (19 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_bilibili_12122021_3.mp4\alphapose-results.json → PD_Severe_severe_bilibili_12122021_3.mp4_alphapose-results
#   Loaded 308 frames
#   → Detected 9 cycles (left_ankle (9 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_bilibili_12122021_4\alphapose-results.json → PD_Severe_severe_bilibili_12122021_4_alphapose-results
#   Loaded 338 frames
#   → Detected 10 cycles (left_ankle (10 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_bilibili_12122021_5.mp4\alphapose-results.json → PD_Severe_severe_bilibili_12122021_5.mp4_alphapose-results
#   Loaded 372 frames
#   → Detected 11 cycles (left_ankle (11 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_03032022_01.mp4\alphapose-results.json → PD_Severe_severe_youtube_03032022_01.mp4_alphapose-results
#   Loaded 740 frames
#   → Detected 26 cycles (left_ankle (26 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_03032022_05.mp4\alphapose-results.json → PD_Severe_severe_youtube_03032022_05.mp4_alphapose-results
#   Loaded 370 frames
#   → Detected 11 cycles (left_ankle (11 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_03032022_07.mp4\alphapose-results.json → PD_Severe_severe_youtube_03032022_07.mp4_alphapose-results
#   Loaded 776 frames
#   → Detected 24 cycles (left_ankle (24 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_03032022_08.mp4\alphapose-results.json → PD_Severe_severe_youtube_03032022_08.mp4_alphapose-results
#   Loaded 899 frames
#   → Detected 27 cycles (left_ankle (27 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_09122021_1.mp4\alphapose-results.json → PD_Severe_severe_youtube_09122021_1.mp4_alphapose-results
#   Loaded 2510 frames
#   → Detected 103 cycles (left_ankle (103 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_09122021_4.mp4\alphapose-results.json → PD_Severe_severe_youtube_09122021_4.mp4_alphapose-results
#   Loaded 1043 frames
#   → Detected 39 cycles (left_ankle (39 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_09122021_5.mp4\alphapose-results.json → PD_Severe_severe_youtube_09122021_5.mp4_alphapose-results
#   Loaded 484 frames
#   → Detected 9 cycles (left_ankle (9 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_10012022_3\alphapose-results.json → PD_Severe_severe_youtube_10012022_3_alphapose-results
#   Loaded 1273 frames
#   → Detected 24 cycles (left_ankle (24 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_10012022_4.mp4\alphapose-results.json → PD_Severe_severe_youtube_10012022_4.mp4_alphapose-results
#   Loaded 1283 frames
#   → Detected 44 cycles (left_ankle (44 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_10122021_3.mp4\alphapose-results.json → PD_Severe_severe_youtube_10122021_3.mp4_alphapose-results
#   Loaded 713 frames
#   → Detected 24 cycles (left_ankle (24 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_10122021_4.mp4\alphapose-results.json → PD_Severe_severe_youtube_10122021_4.mp4_alphapose-results
#   Loaded 652 frames
#   → Detected 20 cycles (left_ankle (20 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_10122021_5.mp4\alphapose-results.json → PD_Severe_severe_youtube_10122021_5.mp4_alphapose-results
#   Loaded 562 frames
#   → Detected 18 cycles (left_ankle (18 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_11012022_3.mp4\alphapose-results.json → PD_Severe_severe_youtube_11012022_3.mp4_alphapose-results
#   Loaded 1021 frames
#   → Detected 31 cycles (left_ankle (31 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_11012022_4.mp4\alphapose-results.json → PD_Severe_severe_youtube_11012022_4.mp4_alphapose-results
#   Loaded 1131 frames
#   → Detected 38 cycles (left_ankle (38 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_11012022_5.mp4\alphapose-results.json → PD_Severe_severe_youtube_11012022_5.mp4_alphapose-results
#   Loaded 1330 frames
#   → Detected 38 cycles (left_ankle (38 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_11012022_6.mp4\alphapose-results.json → PD_Severe_severe_youtube_11012022_6.mp4_alphapose-results
#   Loaded 1235 frames
#   → Detected 39 cycles (left_ankle (39 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_11012022_7.mp4\alphapose-results.json → PD_Severe_severe_youtube_11012022_7.mp4_alphapose-results
#   Loaded 855 frames
#   → Detected 28 cycles (left_ankle (28 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_11122021_1.mp4\alphapose-results.json → PD_Severe_severe_youtube_11122021_1.mp4_alphapose-results
#   Loaded 556 frames
#   → Detected 12 cycles (left_ankle (12 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_12012022_3.mp4\alphapose-results.json → PD_Severe_severe_youtube_12012022_3.mp4_alphapose-results
#   Loaded 391 frames
#   → Detected 10 cycles (left_ankle (10 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_12012022_4.mp4\alphapose-results.json → PD_Severe_severe_youtube_12012022_4.mp4_alphapose-results
#   Loaded 830 frames
#   → Detected 33 cycles (left_ankle (33 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_12012022_5.mp4\alphapose-results.json → PD_Severe_severe_youtube_12012022_5.mp4_alphapose-results
#   Loaded 1175 frames
#   → Detected 29 cycles (left_ankle (29 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_12012022_6.mp4\alphapose-results.json → PD_Severe_severe_youtube_12012022_6.mp4_alphapose-results
#   Loaded 889 frames
#   → Detected 23 cycles (left_ankle (23 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_13012022_3.mp4\alphapose-results.json → PD_Severe_severe_youtube_13012022_3.mp4_alphapose-results
#   Loaded 368 frames
#   → Detected 13 cycles (left_ankle (13 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_13122021_1\alphapose-results.json → PD_Severe_severe_youtube_13122021_1_alphapose-results
#   Loaded 1184 frames
#   → Detected 38 cycles (left_ankle (38 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_13122021_3.mp4\alphapose-results.json → PD_Severe_severe_youtube_13122021_3.mp4_alphapose-results
#   Loaded 495 frames
#   → Detected 10 cycles (left_ankle (10 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_18122021_3.mp4\alphapose-results.json → PD_Severe_severe_youtube_18122021_3.mp4_alphapose-results
#   Loaded 510 frames
#   → Detected 18 cycles (left_ankle (18 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_19032022_10.mp4\alphapose-results.json → PD_Severe_severe_youtube_19032022_10.mp4_alphapose-results
#   Loaded 535 frames
#   → Detected 14 cycles (left_ankle (14 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_19032022_11.mp4\alphapose-results.json → PD_Severe_severe_youtube_19032022_11.mp4_alphapose-results
#   Loaded 384 frames
#   → Detected 9 cycles (left_ankle (9 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_19032022_14.mp4\alphapose-results.json → PD_Severe_severe_youtube_19032022_14.mp4_alphapose-results
#   Loaded 428 frames
#   → Detected 14 cycles (left_ankle (14 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_19032022_15.mp4\alphapose-results.json → PD_Severe_severe_youtube_19032022_15.mp4_alphapose-results
#   Loaded 629 frames
#   → Detected 20 cycles (left_ankle (20 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_19032022_17.mp4\alphapose-results.json → PD_Severe_severe_youtube_19032022_17.mp4_alphapose-results
#   Loaded 261 frames
#   → Detected 8 cycles (left_ankle (8 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_19032022_20.mp4\alphapose-results.json → PD_Severe_severe_youtube_19032022_20.mp4_alphapose-results
#   Loaded 748 frames
#   → Detected 25 cycles (left_ankle (25 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_19032022_23.mp4\alphapose-results.json → PD_Severe_severe_youtube_19032022_23.mp4_alphapose-results
#   Loaded 916 frames
#   → Detected 32 cycles (left_ankle (32 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_19032022_25.mp4\alphapose-results.json → PD_Severe_severe_youtube_19032022_25.mp4_alphapose-results
#   Loaded 2199 frames
#   → Detected 76 cycles (left_ankle (76 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_19032022_26.mp4\alphapose-results.json → PD_Severe_severe_youtube_19032022_26.mp4_alphapose-results
#   Loaded 1438 frames
#   → Detected 44 cycles (left_ankle (44 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_19032022_6.mp4\alphapose-results.json → PD_Severe_severe_youtube_19032022_6.mp4_alphapose-results
#   Loaded 1647 frames
#   → Detected 48 cycles (left_ankle (48 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_19032022_8.mp4\alphapose-results.json → PD_Severe_severe_youtube_19032022_8.mp4_alphapose-results
#   Loaded 539 frames
#   → Detected 9 cycles (left_ankle (9 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_19122021_1.mp4\alphapose-results.json → PD_Severe_severe_youtube_19122021_1.mp4_alphapose-results
#   Loaded 257 frames
#   → Detected 7 cycles (left_ankle (7 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_19122021_4.mp4\alphapose-results.json → PD_Severe_severe_youtube_19122021_4.mp4_alphapose-results
#   Loaded 478 frames
#   → Detected 13 cycles (left_ankle (13 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_19122021_5.mp4\alphapose-results.json → PD_Severe_severe_youtube_19122021_5.mp4_alphapose-results
#   Loaded 950 frames
#   → Detected 24 cycles (left_ankle (24 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_20012022_1.mp4\alphapose-results.json → PD_Severe_severe_youtube_20012022_1.mp4_alphapose-results
#   Loaded 2632 frames
#   → Detected 82 cycles (left_ankle (82 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_22012022_1.mp4\alphapose-results.json → PD_Severe_severe_youtube_22012022_1.mp4_alphapose-results
#   Loaded 1479 frames
#   → Detected 43 cycles (left_ankle (43 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_22012022_3.mp4\alphapose-results.json → PD_Severe_severe_youtube_22012022_3.mp4_alphapose-results
#   Loaded 5143 frames
#   → Detected 182 cycles (left_ankle (182 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_22012022_4\alphapose-results.json → PD_Severe_severe_youtube_22012022_4_alphapose-results
#   Loaded 996 frames
#   → Detected 38 cycles (left_ankle (38 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_23022022_06.mp4\alphapose-results.json → PD_Severe_severe_youtube_23022022_06.mp4_alphapose-results
#   Loaded 624 frames
#   → Detected 19 cycles (left_ankle (19 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_23022022_07.mp4\alphapose-results.json → PD_Severe_severe_youtube_23022022_07.mp4_alphapose-results
#   Loaded 96 frames
#   → Detected 3 cycles (left_ankle (3 cycles))
#   Padding 3 cycles (repeating last valid cycle)
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_23022022_13.mp4\alphapose-results.json → PD_Severe_severe_youtube_23022022_13.mp4_alphapose-results
#   Loaded 328 frames
#   → Detected 7 cycles (left_ankle (7 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_23022022_14.mp4\alphapose-results.json → PD_Severe_severe_youtube_23022022_14.mp4_alphapose-results
#   Loaded 508 frames
#   → Detected 13 cycles (left_ankle (13 cycles))
#  Saved 6 cycles + 14 groups
#
# PD\Severe\severe_youtube_23022022_18.mp4\alphapose-results.json → PD_Severe_severe_youtube_23022022_18.mp4_alphapose-results
#   Loaded 1310 frames
#   → Detected 37 cycles (left_ankle (37 cycles))
#  Saved 6 cycles + 14 groups
#
# Metadata saved: D:\PD\PD_latest\dataset\processed_cycles\online_dataset\metadata\cycle_metadata.csv
#    Total unique files: 280
#    Total cycles: 1680 (6 per file)
#
# Label distribution:
# label
# 0    140
# 1    140
# Name: file_id, dtype: int64
#
# Severity distribution (PD only):
# severity
# Mild        31
# Moderate    57
# Severe      52
# Name: file_id, dtype: int64

# %%
meta_df.shape
# Out:
# (1680, 12)

# %%
meta_df.head()
# Out:
#                          file_id  cycle_id  start_frame  end_frame  \
# 0  NP_normal_1_alphapose-results         1            6         31
# 1  NP_normal_1_alphapose-results         2           31         72
# 2  NP_normal_1_alphapose-results         3           72        109
# 3  NP_normal_1_alphapose-results         4          109        172
# 4  NP_normal_1_alphapose-results         5          172        213
#
#    n_frames_raw  is_padded         detected_using  original_cycle_count label  \
# 0            25      False  left_ankle (4 cycles)                     4     0
# 1            41      False  left_ankle (4 cycles)                     4     0
# 2            37      False  left_ankle (4 cycles)                     4     0
# 3            63      False  left_ankle (4 cycles)                     4     0
# 4            63       True  left_ankle (4 cycles)                     4     0
#
#   severity                              source       folder
# 0     None  NP\normal_1\alphapose-results.json  NP\normal_1
# 1     None  NP\normal_1\alphapose-results.json  NP\normal_1
# 2     None  NP\normal_1\alphapose-results.json  NP\normal_1
# 3     None  NP\normal_1\alphapose-results.json  NP\normal_1
# 4     None  NP\normal_1\alphapose-results.json  NP\normal_1

# %% [markdown]
# # Visualization

# %%
# Visualize cycle detection for the last processed file
# Re-load the last file's data to get y_signal
json_path_viz = None

# Prefer the exact relative_path if available
if 'relative_path' in locals():
	cand = JSON_DIR / relative_path
	if cand.exists():
		json_path_viz = cand

# Fallback: search in discovered json_files by stem
if json_path_viz is None or not json_path_viz.exists():
	matches = [p for p in json_files if p.stem == file_id]
	if matches:
		json_path_viz = matches[-1]
	else:
		raise FileNotFoundError(f"No JSON found for file_id={file_id}")

xy_seq_viz = load_alphapose_json(json_path_viz)

# Extract y-signal for left ankle (index 15)
y_signal_viz = xy_seq_viz[:, 15 * 2 + 1]

# Apply smoothing
max_win = len(y_signal_viz) if len(y_signal_viz) % 2 == 1 else len(y_signal_viz) - 1
win = min(9, max_win)
if win < 3:
	win = 3
if win % 2 == 0:
	win += 1

try:
	y_smooth_viz = savgol_filter(y_signal_viz, win, polyorder=2)
except Exception:
	y_smooth_viz = y_signal_viz.copy()

# Plot
plt.figure(figsize=(10, 3))
plt.plot(y_signal_viz, 'b-', alpha=0.4, label='Raw ankle y')
plt.plot(y_smooth_viz, 'r-', linewidth=2, label='Smoothed')
if len(peaks) > 0:
	plt.plot(peaks, y_smooth_viz[peaks], 'go', markersize=8, label='Detected peaks')
plt.title(f"{file_id}: {len(peaks)-1} cycles detected ({used_method})")
plt.xlabel("Frame")
plt.ylabel("Y coordinate")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
video_path = "D:\\PD\\data\\outputs\\online_dataset\\data_keypoints\\Videos\\Severe\\severe_bilibili_12122021_3.mp4\\AlphaPose_severe_bilibili_12122021_3.mp4"
json_path = "D:\\PD\\data\\outputs\\online_dataset\\data_keypoints\\Videos\\Severe\\severe_bilibili_12122021_3.mp4\\alphapose-results.json"

# %%
def plot_coco_skeleton(pose_flat, title=""):
    """
    Safely plot COCO-17 skeleton — with diagnostics.
    pose_flat: (34,) array: [x0,y0,x1,y1,...,x16,y16]
    """
    assert len(pose_flat) == 34, f"Expected 34 values, got {len(pose_flat)}"
    
    # Reshape safely
    kp = pose_flat.reshape(17, 2)  # (17, 2)
    
    # Replace NaN with np.nan (for skipping)
    kp = np.where(np.isfinite(kp), kp, np.nan)
    
    fig, ax = plt.subplots(figsize=(6, 6))
    
    # Plot joints
    ax.scatter(kp[:, 0], kp[:, 1], c='red', s=100, zorder=5, edgecolors='white', linewidth=2)
    
    # Label joints (only if not NaN)
    for i in range(17):
        x, y = kp[i]
        if not np.isnan(x) and not np.isnan(y):
            ax.text(x + 3, y + 3, f"{i}", fontsize=8, fontweight='bold', zorder=6)
    
    # Draw limbs — skip if either joint is NaN
    for i1, i2 in COCO_EDGES:
        x1, y1 = kp[i1]
        x2, y2 = kp[i2]
        if not (np.isnan(x1) or np.isnan(y1) or np.isnan(x2) or np.isnan(y2)):
            ax.plot([x1, x2], [y1, y2], 'r-', linewidth=2.5, zorder=4)
    
    ax.set_title(title, fontsize=12, fontweight='bold')
    ax.set_xlabel("X")
    ax.set_ylabel("Y")
    
    # AlphaPose outputs image coordinates → y increases downward → invert for plot
    ax.invert_yaxis()
    
    ax.grid(True, alpha=0.3)
    ax.set_aspect('equal', adjustable='datalim')
    plt.tight_layout()
    return fig, ax

# %%
# Use json_path to find & visualize cycle 1's first frame
file_id = Path(json_path).stem
p = CYCLES_DIR / f"{file_id}_cycle_1.json"

# fallback: find first matching cycle file if exact one is missing
arr = None

# try to locate an existing cycle file
if not p.exists():
    matches = sorted(CYCLES_DIR.glob(f"{file_id}_cycle_*.json"))
    if matches:
        p = matches[0]

if p.exists():
    with open(p, 'r', encoding='utf-8') as f:
        obj = json.load(f)

    # get xy array (support dict with 'xy' or bare list/array)
    if isinstance(obj, dict) and 'xy' in obj:
        arr = np.array(obj['xy'])
    else:
        arr = np.array(obj)
else:
    # fallback: load raw AlphaPose JSON and use its frames directly
    print(f"No cycle JSON found for {file_id} in {CYCLES_DIR} → using raw AlphaPose frames")
    raw_seq = load_alphapose_json(json_path)
    if raw_seq.size == 0:
        raise FileNotFoundError(f"No cycle JSON and raw AlphaPose has no frames for {json_path}")
    arr = raw_seq

# ensure we pick a single 34-length frame
if arr.ndim == 1 and arr.size == 34:
    first_frame = arr
elif arr.ndim == 2 and arr.shape[1] == 34:
    first_frame = arr[0]
else:
    first_frame = arr.flatten()[:34]

# defensive cast and NaN handling
first_frame = np.asarray(first_frame, dtype=float)
first_frame[~np.isfinite(first_frame)] = np.nan

fig, ax = plot_coco_skeleton(first_frame, title=f"{file_id}")
plt.show()
# Out:
# No cycle JSON found for alphapose-results in D:\PD\PD_latest\dataset\processed_cycles\online_dataset\cycles → using raw AlphaPose frames

# %%
# peaks = np.array([27, 71, 115, 159, 203, 247, 291])  # example
peaks = None  # ← set to None or your array

start_frame = 27
end_frame = 71
step = 10  # frames to skip
confidence_thresh = 0.2  # min keypoint confidence

def parse_frame_number(image_id):
    """Robustly extract frame number from image_id string."""
    if isinstance(image_id, int):
        return image_id
    if not isinstance(image_id, str):
        return None
    # Remove extension
    stem = Path(image_id).stem
    # Find all numbers
    nums = re.findall(r'\d+', stem)
    if not nums:
        return None
    # Heuristic: last number is frame index (e.g., file_frameXYZ → XYZ)
    return int(nums[-1])
def load_keypoints_dict(json_path):
    """Load AlphaPose JSON → {frame_num: (17, 3) array}."""
    with open(json_path) as f:
        data = json.load(f)
    
    kp_dict = {}
    
    # Accept either a list of detections or a dict with 'annotations'
    if isinstance(data, list):
        items = data
    elif isinstance(data, dict) and 'annotations' in data and isinstance(data['annotations'], list):
        items = data['annotations']
    else:
        items = []
    
    for item in items:
        if not isinstance(item, dict):
            continue
        # support several possible keys for filename/id
        image_id = item.get('image_id') or item.get('image') or item.get('file_name')
        fid = parse_frame_number(image_id)
        if fid is None:
            continue
        kp_list = item.get('keypoints')
        if kp_list is None:
            continue
        try:
            kpts = np.array(kp_list).reshape(-1, 3)
            # ensure we have at least 17 keypoints; trim extras
            if kpts.ndim == 2 and kpts.shape[1] == 3 and kpts.shape[0] >= 17:
                kpts = kpts[:17, :]
                kp_dict[fid] = kpts
        except Exception:
            continue
    return kp_dict

def draw_skeleton(frame, keypoints, edges, 
                  joint_color=(0, 255, 255), limb_color=(0, 255, 0),
                  thickness=2, radius=4, conf_thresh=0.2):
    """Draw COCO skeleton on OpenCV BGR frame."""
    h, w = frame.shape[:2]
    # Draw limbs
    for i1, i2 in edges:
        x1, y1, s1 = keypoints[i1]
        x2, y2, s2 = keypoints[i2]
        if s1 >= conf_thresh and s2 >= conf_thresh:
            pt1 = (int(np.clip(x1, 0, w-1)), int(np.clip(y1, 0, h-1)))
            pt2 = (int(np.clip(x2, 0, w-1)), int(np.clip(y2, 0, h-1)))
            cv2.line(frame, pt1, pt2, limb_color, thickness)
            cv2.circle(frame, pt1, radius, joint_color, -1)
            cv2.circle(frame, pt2, radius, joint_color, -1)
    return frame

def annotate_frame(frame, frame_idx, is_peak=False):
    """Add frame number and optional peak marker."""
    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(frame, f"Frame: {frame_idx}", (10, 30), 
                font, 0.8, (255, 255, 255), 2, cv2.LINE_AA)
    if is_peak:
        cv2.putText(frame, "PEAK", (10, 60), font, 0.8, (0, 0, 255), 2, cv2.LINE_AA)
        cv2.rectangle(frame, (5, 5), (frame.shape[1]-5, frame.shape[0]-5), (0, 0, 255), 3)
    return frame

# ──────────────── MAIN ────────────────

# Load data
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    raise FileNotFoundError(f"Cannot open video: {video_path}")

kp_dict = load_keypoints_dict(json_path)
if not kp_dict:
    raise ValueError("No keypoints loaded from JSON")

print(f"Loaded {len(kp_dict)} frames from JSON")
print(f"   Frames available: {sorted(kp_dict.keys())[:5]}...")

# Set frame range
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
if end_frame is None:
    end_frame = total_frames - 1
frame_range = range(start_frame, min(end_frame + 1, total_frames), step)

# Plot frames
for fid in frame_range:
    # Read frame
    cap.set(cv2.CAP_PROP_POS_FRAMES, fid)
    ret, frame = cap.read()
    if not ret:
        print(f"Failed to read frame {fid}")
        continue
    
    # Get keypoints (fallback: nearest frame if missing)
    if fid in kp_dict:
        kpts = kp_dict[fid]
    else:
        # Find nearest available frame
        available = np.array(list(kp_dict.keys()))
        if len(available) == 0:
            print(f"No keypoints for any frame")
            continue
        nearest = available[np.argmin(np.abs(available - fid))]
        kpts = kp_dict[nearest]
        print(f"Frame {fid} missing → using nearest: {nearest}")
    
    # Draw skeleton
    frame_vis = draw_skeleton(
        frame.copy(), 
        kpts, 
        COCO_EDGES,
        conf_thresh=confidence_thresh
    )
    
    # Annotate
    is_peak = peaks is not None and fid in peaks
    frame_vis = annotate_frame(frame_vis, fid, is_peak=is_peak)
    
    # Convert BGR → RGB for matplotlib
    rgb = cv2.cvtColor(frame_vis, cv2.COLOR_BGR2RGB)
    
    # Plot
    plt.figure(figsize=(10, 6))
    plt.imshow(rgb)
    plt.title(f"{Path(video_path).stem} – Frame {fid}", fontsize=14, fontweight='bold')
    plt.axis('off')
    plt.tight_layout()
    plt.show()

cap.release()
# Out:
# Loaded 308 frames from JSON
#    Frames available: [0, 1, 2, 3, 4]...
